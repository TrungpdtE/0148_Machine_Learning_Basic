# %% [markdown]
# # Generate Time Series

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import tensorflow.keras as keras



# Create time series - number of time series = batch size
# n_steps = number of steps
# freq and offsets - randomly generated and used in the sinusoidal function

def generate_time_series(batch_size, n_steps):
    freq1, freq2, offsets1, offsets2 = np.random.rand(4, batch_size, 1)
    time = np.linspace(0, 1, n_steps)
    series = 0.5 * np.sin((time - offsets1) * (freq1 * 10 + 10)) # wave 1
    series += 0.2 * np.sin((time - offsets2) * (freq2 * 20 + 20)) # wave 2
    series += 0.1 * (np.random.rand(batch_size, n_steps) - 0.5) # noise
    return series[:, np.newaxis].astype(np.float32).reshape(batch_size, n_steps,1)

# %%
# Let us try to visualise the time series, for simplicity sake just look at 3 stime series
# generate sample 

batch_size = 3
s = generate_time_series(batch_size, 20)

times_df = pd.DataFrame(s.reshape(batch_size,-1)).T
times_df.columns= ['series_' + str(x) for x in range(1,batch_size + 1)]
times_df.plot.line()
# Out:
# <Axes: >

# %% [markdown]
# # Modelling

# %%
# We will randomly generate 10000 series
# You can think of this as time series of 10000 stocks (We will be actually doing that too)
# X_Train contains 7000 time series of shape 7000,50,1
# X_Valid contains 2000 time series
# X_Test contains 1000 time series 

# X is the first n_steps and we are trying to predict n+1 step
# Y is a column vector, the 51st step -> -1 implies select last column

n_steps = 50
series = generate_time_series(10000, n_steps + 1)
X_train, y_train = series[:7000, :n_steps], series[:7000, -1]
X_valid, y_valid = series[7000:9000, :n_steps], series[7000:9000, -1]
X_test, y_test = series[9000:, :n_steps], series[9000:, -1]

# %% [markdown]
# ### Baseline Metrics

# %%
# Naive - the last value of X_valid

y_pred = X_valid[:, -1]
# np.mean(keras.losses.mean_squared_error(y_valid, y_pred))

# %%
import tensorflow as tf
# simple RNN 

model = keras.models.Sequential([
keras.layers.SimpleRNN(1, input_shape=[None, 1])
])

model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(1e-4), metrics = ['RootMeanSquaredError'])

history = model.fit(x=X_train, y=y_train, batch_size=32,epochs=15, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/15
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.5351 - loss: 0.2864 - val_RootMeanSquaredError: 0.5183 - val_loss: 0.2686
# Epoch 2/15
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.5104 - loss: 0.2605 - val_RootMeanSquaredError: 0.4978 - val_loss: 0.2478
# Epoch 3/15
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.4974 - loss: 0.2475 - val_RootMeanSquaredError: 0.4774 - val_loss: 0.2279
# Epoch 4/15
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.4704 - loss: 0.2213 - val_RootMeanSquaredError: 0.4569 - val_loss: 0.2088
# Epoch 5/15
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.4537 - loss: 0.2058 - val_RootMeanSquaredError: 0.4371 - val_loss: 0.1910
# Epoch 6/15
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.4366 - loss: 0.1907 - val_RootMeanSquaredError: 0.4178 - val_loss: 0.1746
# Epoch 7/15
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.4148 - loss: 0.1721 - val_RootMeanSquaredError: 0.3998 - val_loss: 0.1598
# Epoch 8/15
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.3989 - loss: 0.1591 - val_RootMeanSquaredError: 0.3830 - val_loss: 0.1467
# Epoch 9/15
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.3794 - loss: 0.1439 - val_RootMeanSquaredError: 0.3676 - val_loss: 0.1351
# Epoch 10/15
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.3653 - loss: 0.1334 - val_RootMeanSquaredError: 0.3540 - val_loss: 0.1253
# Epoch 11/15
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.3532 - loss: 0.1248 - val_RootMeanSquaredError: 0.3420 - val_loss: 0.1170
# Epoch 12/15
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.3418 - loss: 0.1168 - val_RootMeanSquaredError: 0.3316 - val_loss: 0.1100
# Epoch 13/15
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.3350 - loss: 0.1122 - val_RootMeanSquaredError: 0.3227 - val_loss: 0.1042
# Epoch 14/15
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.3193 - loss: 0.1020 - val_RootMeanSquaredError: 0.3151 - val_loss: 0.0993
# Epoch 15/15
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.3093 - loss: 0.0957 - val_RootMeanSquaredError: 0.3084 - val_loss: 0.0951

# %%
# benchmark mse
y_pred = model.predict(X_valid)
# np.mean(keras.losses.mean_squared_error(y_valid, y_pred))
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 3
#       1 # benchmark mse
#       2 y_pred = model.predict(X_valid)
# ----> 3 np.mean(keras.mean_squared_error(y_valid, y_pred))
#
# AttributeError: module 'tensorflow.keras' has no attribute 'mean_squared_error'

# %%
y_pred = model.predict(X_test)
np.mean(keras.losses.mean_squared_error(y_test, y_pred))
# Out:
# 0.8423383

# %% [markdown]
# # Deep RNN

# %%
# since multiple layers, we can run for more epochs 

model = keras.models.Sequential([
keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None,
1]),
keras.layers.SimpleRNN(20, return_sequences=True),
keras.layers.SimpleRNN(1)
])

model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(1e-4), metrics = ['mean_squared_error'])

history = model.fit(x=X_train, y=y_train, batch_size=32,epochs=50, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/50
# 219/219 [==============================] - 6s 17ms/step - loss: 0.3081 - mean_squared_error: 0.3081 - val_loss: 0.0742 - val_mean_squared_error: 0.0742
# Epoch 2/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0473 - mean_squared_error: 0.0473 - val_loss: 0.0295 - val_mean_squared_error: 0.0295
# Epoch 3/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0235 - mean_squared_error: 0.0235 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
# Epoch 4/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0152 - val_mean_squared_error: 0.0152
# Epoch 5/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0120 - val_mean_squared_error: 0.0120
# Epoch 6/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0123 - val_mean_squared_error: 0.0123
# Epoch 7/50
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0099 - mean_squared_error: 0.0099 - val_loss: 0.0092 - val_mean_squared_error: 0.0092
# Epoch 8/50
# 219/219 [==============================] - 3s 16ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0085 - val_mean_squared_error: 0.0085
# Epoch 9/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0083 - val_mean_squared_error: 0.0083
# Epoch 10/50
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0068 - val_mean_squared_error: 0.0068
# Epoch 11/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0068 - val_mean_squared_error: 0.0068
# Epoch 12/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 13/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 14/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 15/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 16/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 17/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 18/50
# 219/219 [==============================] - 3s 16ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 19/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 20/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 21/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 22/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 23/50
# 219/219 [==============================] - 4s 16ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 24/50
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 25/50
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 26/50
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 27/50
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 28/50
# 219/219 [==============================] - 3s 16ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 29/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 30/50
# 219/219 [==============================] - 3s 16ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 31/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 32/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 33/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 34/50
# 219/219 [==============================] - 3s 16ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 35/50
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 36/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 37/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 38/50
# 219/219 [==============================] - 4s 16ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 39/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 40/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 41/50
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 42/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 43/50
# 219/219 [==============================] - 3s 16ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 44/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 45/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 46/50
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 47/50
# 219/219 [==============================] - 4s 16ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 48/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 49/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 50/50
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0032 - val_mean_squared_error: 0.0032

# %%
# benchmark mse
y_pred = model.predict(X_valid)
np.mean(keras.losses.mean_squared_error(y_valid, y_pred))
# Out:
# 0.0031656942

# %%
y_pred = model.predict(X_test)
np.mean(keras.losses.mean_squared_error(y_test, y_pred))
# Out:
# 0.0032122931

# %% [markdown]
# ## Forecasting ahead

# %% [markdown]
# ### method 1 : Treat the new x_pred as input and output the next step recursively

# %%
# forecast is the number of steps we want to forecast ahead
# Generate X_new and Y_new for 3000 time series, like validation set above

forecast = 10
series = generate_time_series(3000, n_steps + forecast)
X_new, Y_new = series[:, :n_steps], series[:, n_steps:]
X = X_new
for step_ahead in range(forecast):
    y_pred_one = model.predict(X[:, step_ahead:])[:, np.newaxis, :]
    X = np.concatenate([X, y_pred_one], axis=1)
Y_pred = X[:, n_steps:]

# %%
# The error seems way too high, because this is cumulative error for 50 steps as compared to only 1 step previously

np.mean(keras.losses.mean_squared_error(Y_new, Y_pred))
# Out:
# 0.14289214

# %%
# As we can see, errors keep accumulating, after step 10 pretty poor output

times_df = pd.DataFrame(np.hstack((Y_new.reshape(-1, 1), Y_pred.reshape(-1, 1))), columns = ['Actual','Predicted'])

times_df.plot.line()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Method 2: Use sequence to vector model
#
# Predict all 50 values at once

# %%
# now Y is not a column vector, it consists of all forecasted outputs

forecast = 10
series = generate_time_series(10000, n_steps + forecast)
X_train, Y_train = series[:7000, :n_steps], series[:7000, -forecast:, 0]
X_valid, Y_valid = series[7000:9000, :n_steps], series[7000:9000, -forecast:,0]
X_test, Y_test = series[9000:, :n_steps], series[9000:, -forecast:, 0]

# %%
Y_train.shape
# Out:
# (7000, 10)

# %%
model = keras.models.Sequential([
keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None,
1]),
keras.layers.SimpleRNN(20),
keras.layers.Dense(forecast)
])

# %%
model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(1e-4), metrics = ['mean_squared_error'])

history = model.fit(x=X_train, y=Y_train, batch_size=32,epochs=50, validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/50
# 219/219 [==============================] - 4s 11ms/step - loss: 0.1583 - mean_squared_error: 0.1583 - val_loss: 0.1001 - val_mean_squared_error: 0.1001
# Epoch 2/50
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0839 - mean_squared_error: 0.0839 - val_loss: 0.0692 - val_mean_squared_error: 0.0692
# Epoch 3/50
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0606 - mean_squared_error: 0.0606 - val_loss: 0.0547 - val_mean_squared_error: 0.0547
# Epoch 4/50
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0511 - mean_squared_error: 0.0511 - val_loss: 0.0495 - val_mean_squared_error: 0.0495
# Epoch 5/50
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0469 - mean_squared_error: 0.0469 - val_loss: 0.0461 - val_mean_squared_error: 0.0461
# Epoch 6/50
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0437 - mean_squared_error: 0.0437 - val_loss: 0.0426 - val_mean_squared_error: 0.0426
# Epoch 7/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0405 - mean_squared_error: 0.0405 - val_loss: 0.0398 - val_mean_squared_error: 0.0398
# Epoch 8/50
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0380 - mean_squared_error: 0.0380 - val_loss: 0.0373 - val_mean_squared_error: 0.0373
# Epoch 9/50
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0358 - mean_squared_error: 0.0358 - val_loss: 0.0352 - val_mean_squared_error: 0.0352
# Epoch 10/50
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0336 - mean_squared_error: 0.0336 - val_loss: 0.0333 - val_mean_squared_error: 0.0333
# Epoch 11/50
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0315 - mean_squared_error: 0.0315 - val_loss: 0.0308 - val_mean_squared_error: 0.0308
# Epoch 12/50
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0292 - mean_squared_error: 0.0292 - val_loss: 0.0281 - val_mean_squared_error: 0.0281
# Epoch 13/50
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0266 - mean_squared_error: 0.0266 - val_loss: 0.0261 - val_mean_squared_error: 0.0261
# Epoch 14/50
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0244 - mean_squared_error: 0.0244 - val_loss: 0.0237 - val_mean_squared_error: 0.0237
# Epoch 15/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0223 - mean_squared_error: 0.0223 - val_loss: 0.0214 - val_mean_squared_error: 0.0214
# Epoch 16/50
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0205 - mean_squared_error: 0.0205 - val_loss: 0.0199 - val_mean_squared_error: 0.0199
# Epoch 17/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0191 - mean_squared_error: 0.0191 - val_loss: 0.0190 - val_mean_squared_error: 0.0190
# Epoch 18/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0182 - mean_squared_error: 0.0182 - val_loss: 0.0178 - val_mean_squared_error: 0.0178
# Epoch 19/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.0174 - val_mean_squared_error: 0.0174
# Epoch 20/50
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0167 - mean_squared_error: 0.0167 - val_loss: 0.0162 - val_mean_squared_error: 0.0162
# Epoch 21/50
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.0158 - val_mean_squared_error: 0.0158
# Epoch 22/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0156 - mean_squared_error: 0.0156 - val_loss: 0.0158 - val_mean_squared_error: 0.0158
# Epoch 23/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0153 - mean_squared_error: 0.0153 - val_loss: 0.0151 - val_mean_squared_error: 0.0151
# Epoch 24/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0148 - mean_squared_error: 0.0148 - val_loss: 0.0146 - val_mean_squared_error: 0.0146
# Epoch 25/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 0.0142 - val_mean_squared_error: 0.0142
# Epoch 26/50
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.0141 - val_mean_squared_error: 0.0141
# Epoch 27/50
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0136 - val_mean_squared_error: 0.0136
# Epoch 28/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0138 - val_mean_squared_error: 0.0138
# Epoch 29/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0134 - mean_squared_error: 0.0134 - val_loss: 0.0135 - val_mean_squared_error: 0.0135
# Epoch 30/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 0.0133 - val_mean_squared_error: 0.0133
# Epoch 31/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 0.0130 - val_mean_squared_error: 0.0130
# Epoch 32/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0128 - val_mean_squared_error: 0.0128
# Epoch 33/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0128 - val_mean_squared_error: 0.0128
# Epoch 34/50
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0125 - val_mean_squared_error: 0.0125
# Epoch 35/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 0.0124 - val_mean_squared_error: 0.0124
# Epoch 36/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0124 - val_mean_squared_error: 0.0124
# Epoch 37/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0123 - val_mean_squared_error: 0.0123
# Epoch 38/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0121 - val_mean_squared_error: 0.0121
# Epoch 39/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 40/50
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0119 - val_mean_squared_error: 0.0119
# Epoch 41/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 42/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 43/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0115 - val_mean_squared_error: 0.0115
# Epoch 44/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0116 - val_mean_squared_error: 0.0116
# Epoch 45/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0113 - val_mean_squared_error: 0.0113
# Epoch 46/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 47/50
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0113 - val_mean_squared_error: 0.0113
# Epoch 48/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0112 - val_mean_squared_error: 0.0112
# Epoch 49/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0109 - val_mean_squared_error: 0.0109
# Epoch 50/50
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.0110 - val_mean_squared_error: 0.0110

# %%
# benchmark mse
y_pred = model.predict(X_valid)
np.mean(keras.losses.mean_squared_error(Y_valid, y_pred))
# Out:
# 0.011009066

# %%
y_pred = model.predict(X_test)
np.mean(keras.losses.mean_squared_error(Y_test, y_pred))
# Out:
# 0.01161295

# %% [markdown]
# ### Method 3 : Treating Y as a sequence

# %%
# forecast_steps is the number of steps you want to forecast ahead, and in this case also the steps ahead you want for y at each step 
forecast_steps = 10
Y = np.empty((10000, n_steps, forecast_steps)) # each target is a sequence of 10D vectors
for step_ahead in range(1, forecast_steps + 1):
    Y[:, :, step_ahead - 1] = series[:, step_ahead:step_ahead + n_steps,0]
    Y_train = Y[:7000]
    Y_valid = Y[7000:9000]
    Y_test = Y[9000:]

# %%
print(Y_train.shape)
print(Y_valid.shape)
print(Y_test.shape)
# Out:
# (7000, 50, 10)
# (2000, 50, 10)
# (1000, 50, 10)

# %%
# only the last output is used for evaluation (the other outputs are used for training)
Y_test[:, -1].shape
# Out:
# (1000, 10)

# %%
model = keras.models.Sequential([
keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None,
1]),
keras.layers.SimpleRNN(20, return_sequences=True),
keras.layers.TimeDistributed(keras.layers.Dense(10))
])

def last_time_step_mse(Y_true, Y_pred):
    return keras.metrics.mean_squared_error(Y_true[:, -1], Y_pred[:, -1])

optimizer = keras.optimizers.Adam(lr=0.01)
model.compile(loss="mse", optimizer=optimizer, metrics=[last_time_step_mse])

history = model.fit(x=X_train, y=Y_train, batch_size=32,epochs=100, validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/100
# 219/219 [==============================] - 4s 11ms/step - loss: 0.0516 - last_time_step_mse: 0.0401 - val_loss: 0.0401 - val_last_time_step_mse: 0.0260
# Epoch 2/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0372 - last_time_step_mse: 0.0238 - val_loss: 0.0317 - val_last_time_step_mse: 0.0169
# Epoch 3/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0314 - last_time_step_mse: 0.0181 - val_loss: 0.0299 - val_last_time_step_mse: 0.0171
# Epoch 4/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0278 - last_time_step_mse: 0.0139 - val_loss: 0.0266 - val_last_time_step_mse: 0.0125
# Epoch 5/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0260 - last_time_step_mse: 0.0123 - val_loss: 0.0261 - val_last_time_step_mse: 0.0124
# Epoch 6/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0246 - last_time_step_mse: 0.0114 - val_loss: 0.0234 - val_last_time_step_mse: 0.0105
# Epoch 7/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0226 - last_time_step_mse: 0.0099 - val_loss: 0.0214 - val_last_time_step_mse: 0.0083
# Epoch 8/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0218 - last_time_step_mse: 0.0095 - val_loss: 0.0212 - val_last_time_step_mse: 0.0083
# Epoch 9/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0215 - last_time_step_mse: 0.0094 - val_loss: 0.0202 - val_last_time_step_mse: 0.0069
# Epoch 10/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0203 - last_time_step_mse: 0.0079 - val_loss: 0.0224 - val_last_time_step_mse: 0.0100
# Epoch 11/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0199 - last_time_step_mse: 0.0075 - val_loss: 0.0205 - val_last_time_step_mse: 0.0080
# Epoch 12/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0201 - last_time_step_mse: 0.0079 - val_loss: 0.0205 - val_last_time_step_mse: 0.0077
# Epoch 13/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0198 - last_time_step_mse: 0.0077 - val_loss: 0.0200 - val_last_time_step_mse: 0.0075
# Epoch 14/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0195 - last_time_step_mse: 0.0074 - val_loss: 0.0192 - val_last_time_step_mse: 0.0063
# Epoch 15/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0191 - last_time_step_mse: 0.0072 - val_loss: 0.0194 - val_last_time_step_mse: 0.0076
# Epoch 16/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0187 - last_time_step_mse: 0.0069 - val_loss: 0.0178 - val_last_time_step_mse: 0.0054
# Epoch 17/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0186 - last_time_step_mse: 0.0069 - val_loss: 0.0189 - val_last_time_step_mse: 0.0068
# Epoch 18/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0184 - last_time_step_mse: 0.0068 - val_loss: 0.0190 - val_last_time_step_mse: 0.0066
# Epoch 19/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0184 - last_time_step_mse: 0.0067 - val_loss: 0.0185 - val_last_time_step_mse: 0.0072
# Epoch 20/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0180 - last_time_step_mse: 0.0063 - val_loss: 0.0178 - val_last_time_step_mse: 0.0060
# Epoch 21/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0179 - last_time_step_mse: 0.0063 - val_loss: 0.0201 - val_last_time_step_mse: 0.0081
# Epoch 22/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0183 - last_time_step_mse: 0.0070 - val_loss: 0.0187 - val_last_time_step_mse: 0.0067
# Epoch 23/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0177 - last_time_step_mse: 0.0062 - val_loss: 0.0175 - val_last_time_step_mse: 0.0059
# Epoch 24/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0178 - last_time_step_mse: 0.0066 - val_loss: 0.0181 - val_last_time_step_mse: 0.0068
# Epoch 25/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0179 - last_time_step_mse: 0.0067 - val_loss: 0.0179 - val_last_time_step_mse: 0.0059
# Epoch 26/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0176 - last_time_step_mse: 0.0061 - val_loss: 0.0174 - val_last_time_step_mse: 0.0058
# Epoch 27/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0173 - last_time_step_mse: 0.0062 - val_loss: 0.0170 - val_last_time_step_mse: 0.0058
# Epoch 28/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0173 - last_time_step_mse: 0.0060 - val_loss: 0.0179 - val_last_time_step_mse: 0.0064
# Epoch 29/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0175 - last_time_step_mse: 0.0065 - val_loss: 0.0173 - val_last_time_step_mse: 0.0057
# Epoch 30/100
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0173 - last_time_step_mse: 0.0060 - val_loss: 0.0166 - val_last_time_step_mse: 0.0051
# Epoch 31/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0174 - last_time_step_mse: 0.0062 - val_loss: 0.0173 - val_last_time_step_mse: 0.0055
# Epoch 32/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0172 - last_time_step_mse: 0.0059 - val_loss: 0.0189 - val_last_time_step_mse: 0.0077
# Epoch 33/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0175 - last_time_step_mse: 0.0064 - val_loss: 0.0179 - val_last_time_step_mse: 0.0071
# Epoch 34/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0171 - last_time_step_mse: 0.0060 - val_loss: 0.0180 - val_last_time_step_mse: 0.0061
# Epoch 35/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0171 - last_time_step_mse: 0.0058 - val_loss: 0.0200 - val_last_time_step_mse: 0.0095
# Epoch 36/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0168 - last_time_step_mse: 0.0057 - val_loss: 0.0178 - val_last_time_step_mse: 0.0065
# Epoch 37/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0172 - last_time_step_mse: 0.0061 - val_loss: 0.0187 - val_last_time_step_mse: 0.0081
# Epoch 38/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0171 - last_time_step_mse: 0.0059 - val_loss: 0.0200 - val_last_time_step_mse: 0.0080
# Epoch 39/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0171 - last_time_step_mse: 0.0058 - val_loss: 0.0168 - val_last_time_step_mse: 0.0056
# Epoch 40/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0170 - last_time_step_mse: 0.0061 - val_loss: 0.0177 - val_last_time_step_mse: 0.0061
# Epoch 41/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0172 - last_time_step_mse: 0.0061 - val_loss: 0.0172 - val_last_time_step_mse: 0.0055
# Epoch 42/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0171 - last_time_step_mse: 0.0061 - val_loss: 0.0167 - val_last_time_step_mse: 0.0053
# Epoch 43/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0173 - last_time_step_mse: 0.0063 - val_loss: 0.0169 - val_last_time_step_mse: 0.0050
# Epoch 44/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0170 - last_time_step_mse: 0.0058 - val_loss: 0.0170 - val_last_time_step_mse: 0.0057
# Epoch 45/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0170 - last_time_step_mse: 0.0059 - val_loss: 0.0182 - val_last_time_step_mse: 0.0071
# Epoch 46/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0173 - last_time_step_mse: 0.0062 - val_loss: 0.0167 - val_last_time_step_mse: 0.0055
# Epoch 47/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0169 - last_time_step_mse: 0.0059 - val_loss: 0.0165 - val_last_time_step_mse: 0.0052
# Epoch 48/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0169 - last_time_step_mse: 0.0057 - val_loss: 0.0162 - val_last_time_step_mse: 0.0050
# Epoch 49/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0200 - last_time_step_mse: 0.0098 - val_loss: 0.0238 - val_last_time_step_mse: 0.0126
# Epoch 50/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0188 - last_time_step_mse: 0.0080 - val_loss: 0.0170 - val_last_time_step_mse: 0.0061
# Epoch 51/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0172 - last_time_step_mse: 0.0062 - val_loss: 0.0169 - val_last_time_step_mse: 0.0059
# Epoch 52/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0168 - last_time_step_mse: 0.0059 - val_loss: 0.0167 - val_last_time_step_mse: 0.0058
# Epoch 53/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0169 - last_time_step_mse: 0.0058 - val_loss: 0.0172 - val_last_time_step_mse: 0.0059
# Epoch 54/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0168 - last_time_step_mse: 0.0058 - val_loss: 0.0168 - val_last_time_step_mse: 0.0059
# Epoch 55/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0166 - last_time_step_mse: 0.0057 - val_loss: 0.0166 - val_last_time_step_mse: 0.0054
# Epoch 56/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0170 - last_time_step_mse: 0.0060 - val_loss: 0.0186 - val_last_time_step_mse: 0.0078
# Epoch 57/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0273 - last_time_step_mse: 0.0171 - val_loss: 0.0202 - val_last_time_step_mse: 0.0097
# Epoch 58/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0180 - last_time_step_mse: 0.0071 - val_loss: 0.0169 - val_last_time_step_mse: 0.0058
# Epoch 59/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0171 - last_time_step_mse: 0.0060 - val_loss: 0.0194 - val_last_time_step_mse: 0.0089
# Epoch 60/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0172 - last_time_step_mse: 0.0062 - val_loss: 0.0181 - val_last_time_step_mse: 0.0077
# Epoch 61/100
# 219/219 [==============================] - 3s 11ms/step - loss: 0.0169 - last_time_step_mse: 0.0058 - val_loss: 0.0207 - val_last_time_step_mse: 0.0088
# Epoch 62/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0171 - last_time_step_mse: 0.0061 - val_loss: 0.0171 - val_last_time_step_mse: 0.0058
# Epoch 63/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0165 - last_time_step_mse: 0.0055 - val_loss: 0.0167 - val_last_time_step_mse: 0.0054
# Epoch 64/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0167 - last_time_step_mse: 0.0058 - val_loss: 0.0164 - val_last_time_step_mse: 0.0051
# Epoch 65/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0169 - last_time_step_mse: 0.0060 - val_loss: 0.0166 - val_last_time_step_mse: 0.0058
# Epoch 66/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0166 - last_time_step_mse: 0.0057 - val_loss: 0.0168 - val_last_time_step_mse: 0.0054
# Epoch 67/100
# 219/219 [==============================] - ETA: 0s - loss: 0.0165 - last_time_step_mse: 0.00 - 2s 11ms/step - loss: 0.0165 - last_time_step_mse: 0.0055 - val_loss: 0.0164 - val_last_time_step_mse: 0.0055
# Epoch 68/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0167 - last_time_step_mse: 0.0057 - val_loss: 0.0174 - val_last_time_step_mse: 0.0062
# Epoch 69/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0169 - last_time_step_mse: 0.0059 - val_loss: 0.0171 - val_last_time_step_mse: 0.0057
# Epoch 70/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0168 - last_time_step_mse: 0.0060 - val_loss: 0.0160 - val_last_time_step_mse: 0.0048
# Epoch 71/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0169 - last_time_step_mse: 0.0060 - val_loss: 0.0168 - val_last_time_step_mse: 0.0058
# Epoch 72/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0167 - last_time_step_mse: 0.0058 - val_loss: 0.0174 - val_last_time_step_mse: 0.0058
# Epoch 73/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0165 - last_time_step_mse: 0.0055 - val_loss: 0.0161 - val_last_time_step_mse: 0.0048
# Epoch 74/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0166 - last_time_step_mse: 0.0057 - val_loss: 0.0166 - val_last_time_step_mse: 0.0051
# Epoch 75/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0169 - last_time_step_mse: 0.0060 - val_loss: 0.0181 - val_last_time_step_mse: 0.0068
# Epoch 76/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0166 - last_time_step_mse: 0.0057 - val_loss: 0.0167 - val_last_time_step_mse: 0.0052
# Epoch 77/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0167 - last_time_step_mse: 0.0057 - val_loss: 0.0164 - val_last_time_step_mse: 0.0052
# Epoch 78/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0165 - last_time_step_mse: 0.0056 - val_loss: 0.0171 - val_last_time_step_mse: 0.0063
# Epoch 79/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0166 - last_time_step_mse: 0.0055 - val_loss: 0.0169 - val_last_time_step_mse: 0.0054
# Epoch 80/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0166 - last_time_step_mse: 0.0057 - val_loss: 0.0167 - val_last_time_step_mse: 0.0053
# Epoch 81/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0168 - last_time_step_mse: 0.0060 - val_loss: 0.0173 - val_last_time_step_mse: 0.0060
# Epoch 82/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0167 - last_time_step_mse: 0.0058 - val_loss: 0.0166 - val_last_time_step_mse: 0.0055
# Epoch 83/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0168 - last_time_step_mse: 0.0058 - val_loss: 0.0167 - val_last_time_step_mse: 0.0056
# Epoch 84/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0165 - last_time_step_mse: 0.0056 - val_loss: 0.0175 - val_last_time_step_mse: 0.0062
# Epoch 85/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0165 - last_time_step_mse: 0.0057 - val_loss: 0.0164 - val_last_time_step_mse: 0.0054
# Epoch 86/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0164 - last_time_step_mse: 0.0055 - val_loss: 0.0178 - val_last_time_step_mse: 0.0065
# Epoch 87/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0165 - last_time_step_mse: 0.0056 - val_loss: 0.0164 - val_last_time_step_mse: 0.0052
# Epoch 88/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0171 - last_time_step_mse: 0.0064 - val_loss: 0.0165 - val_last_time_step_mse: 0.0055
# Epoch 89/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0166 - last_time_step_mse: 0.0055 - val_loss: 0.0171 - val_last_time_step_mse: 0.0058
# Epoch 90/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0166 - last_time_step_mse: 0.0058 - val_loss: 0.0177 - val_last_time_step_mse: 0.0068
# Epoch 91/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0164 - last_time_step_mse: 0.0055 - val_loss: 0.0168 - val_last_time_step_mse: 0.0058
# Epoch 92/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0166 - last_time_step_mse: 0.0059 - val_loss: 0.0164 - val_last_time_step_mse: 0.0053
# Epoch 93/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0166 - last_time_step_mse: 0.0058 - val_loss: 0.0170 - val_last_time_step_mse: 0.0056
# Epoch 94/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0185 - last_time_step_mse: 0.0073 - val_loss: 0.0177 - val_last_time_step_mse: 0.0060
# Epoch 95/100
# 219/219 [==============================] - 3s 11ms/step - loss: 0.0163 - last_time_step_mse: 0.0054 - val_loss: 0.0164 - val_last_time_step_mse: 0.0054
# Epoch 96/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0164 - last_time_step_mse: 0.0054 - val_loss: 0.0165 - val_last_time_step_mse: 0.0055
# Epoch 97/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0166 - last_time_step_mse: 0.0056 - val_loss: 0.0172 - val_last_time_step_mse: 0.0060
# Epoch 98/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0164 - last_time_step_mse: 0.0055 - val_loss: 0.0185 - val_last_time_step_mse: 0.0072
# Epoch 99/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0166 - last_time_step_mse: 0.0056 - val_loss: 0.0166 - val_last_time_step_mse: 0.0056
# Epoch 100/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0166 - last_time_step_mse: 0.0058 - val_loss: 0.0175 - val_last_time_step_mse: 0.0063

# %%
# benchmark mse
y_pred = model.predict(X_valid)
np.mean(last_time_step_mse(Y_valid, y_pred))
# Out:
# 0.006343851

# %%
y_pred = model.predict(X_test)
np.mean(last_time_step_mse(Y_test, y_pred))
# Out:
# 0.005994712
